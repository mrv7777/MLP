# %% [markdown]
# <a href="https://colab.research.google.com/github/mrv7777/MLP/blob/main/MLPWeek1_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('V5_1.csv')

# %%
df.shape
# Out:
# (10000, 12)

# %%
df
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# 1        Two Family          Duplex          4              3       1241.0
# 2     Single Family  Detached House          3              2        910.0
# 3     Single Family  Detached House          3              1        971.0
# 4                 ?  Detached House          3              2       1092.0
# ...             ...             ...        ...            ...          ...
# 9995              ?  Detached House          3              3        917.0
# 9996              ?          Duplex          4              4       1416.0
# 9997  Single Family  Detached House          3              1        964.0
# 9998  Single Family  Detached House          3              3       1014.0
# 9999  Single Family  Detached House          3              1        932.0
#
#       property_tax_rate   Face
# 0              1.025953  South
# 1              1.025953  South
# 2              1.025953  South
# 3              1.025953   East
# 4              1.025953   East
# ...                 ...    ...
# 9995           1.003979  North
# 9996           1.003979  North
# 9997           1.003979  South
# 9998           1.003979  North
# 9999           1.003979   East
#
# [10000 rows x 12 columns]

# %% [markdown]
# **1- Select all the even indexed rows from the given dataset. What is the value in the 3rd indexed column of the 0th indexed row in the selected dataframe. (row/ column indexed from zero(0) in python/pandas)**

# %%
df_even = df.iloc[0::2]

# %%
# prompt: how to reset the index of df

df_even = df_even.reset_index(drop=True)

# %%
df_even
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009   Waterbury          55720.0    140000.0
# 2     2009-01-02  2009  Bridgeport         112351.0    210000.0
# 3     2009-01-02  2009     Norwalk         571060.0   1000000.0
# 4     2009-01-02  2009         NaN         603540.0   1680000.0
# ...          ...   ...         ...              ...         ...
# 4995  2022-09-30  2022         NaN         352030.0    700000.0
# 4996  2022-09-30  2022   Fairfield              NaN    680000.0
# 4997  2022-09-30  2022         NaN         155550.0    215000.0
# 4998  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 4999  2022-09-30  2022         NaN         216420.0    415000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# 1     Single Family  Detached House          3              2        910.0
# 2                 ?  Detached House          3              2       1092.0
# 3     Single Family  Detached House          3              2          NaN
# 4     Single Family  Detached House          3              1       1039.0
# ...             ...             ...        ...            ...          ...
# 4995              ?  Detached House          3              3        958.0
# 4996  Single Family  Detached House          3              2        908.0
# 4997   Three Family         Triplex          6              5       2114.0
# 4998              ?          Duplex          4              4       1416.0
# 4999  Single Family  Detached House          3              3       1014.0
#
#       property_tax_rate   Face
# 0              1.025953  South
# 1              1.025953  South
# 2              1.025953   East
# 3              1.025953  South
# 4              1.025953   East
# ...                 ...    ...
# 4995           1.003979  North
# 4996           1.003979   West
# 4997           1.003979  North
# 4998           1.003979  North
# 4999           1.003979  North
#
# [5000 rows x 12 columns]

# %%
df_even.iloc[0,3]
# Out:
# 111440.0

# %% [markdown]
# **2- Select all the even indexed rows from the given dataset. What is the value in the 3rd indexed column of the 332th indexed row in the selected dataframe. (row/ column indexed from zero(0))**

# %%
df_even.iloc[332,3]
# Out:
# 256200.0

# %% [markdown]
# **3- Select all the odd indexed rows from the given dataset. What is the value in the 3rd indexed column of the 332th indexed row in the selected dataframe. (row/ column indexed from zero(0))
#  Please consider case sensitivity while giving your solution capital letter ≠ small letter If it is a string don't write quotes in the solution.**

# %%
df_odd = df.iloc[1::2]

# %%
df_odd
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 1     2009-01-02  2009     Bridgeport         124670.0    150000.0
# 3     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# 5     2009-01-02  2009      Greenwich        2868880.0   3300000.0
# 7     2009-01-02  2009      Greenwich         592760.0    920000.0
# 9     2009-01-02  2009     Bridgeport         137901.0    245000.0
# ...          ...   ...            ...              ...         ...
# 9991  2022-09-30  2022        Norwalk         344270.0    512500.0
# 9993  2022-09-30  2022  West Hartford         121870.0    235000.0
# 9995  2022-09-30  2022     Bridgeport         153660.0    322000.0
# 9997  2022-09-30  2022      Waterbury          83210.0    170000.0
# 9999  2022-09-30  2022        Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 1        Two Family          Duplex          4              3       1241.0
# 3     Single Family  Detached House          3              1        971.0
# 5     Single Family  Detached House          3              1       1039.0
# 7     Single Family  Detached House          3              3        937.0
# 9     Single Family  Detached House          3              1        956.0
# ...             ...             ...        ...            ...          ...
# 9991  Single Family  Detached House          3              3          NaN
# 9993  Single Family  Detached House          3              2       1087.0
# 9995              ?  Detached House          3              3        917.0
# 9997  Single Family  Detached House          3              1        964.0
# 9999  Single Family  Detached House          3              1        932.0
#
#       property_tax_rate   Face
# 1              1.025953  South
# 3              1.025953   East
# 5              1.025953  North
# 7              1.025953  North
# 9              1.025953   West
# ...                 ...    ...
# 9991           1.003979   West
# 9993           1.003979  South
# 9995           1.003979  North
# 9997           1.003979  South
# 9999           1.003979   East
#
# [5000 rows x 12 columns]

# %%
df_odd = df_odd.reset_index(drop=True)

# %%
df_odd.iloc[332,3]
# Out:
# 352940.0

# %% [markdown]
# **4- Select all the odd indexed columns from the given dataset. What is the value in the 5th indexed column of the 100th indexed row in the selected dataframe. (row/ column indexed from zero(0))
# Please consider case sensitivity while giving your solution capital letter ≠ small letter
# If it is a string don't write quotes in the solution.**

# %%
df_even_col = df.iloc[:,1::2]

# %%
df_even_col.iloc[100,5]
# Out:
# 'West'

# %% [markdown]
# **5- Select all the even indexed columns and even indexed rows from the given dataset. What is the value in the 3th indexed column of the 255th indexed row in the selected dataframe. (row/ column indexed/starts from zero(0))
# Please consider case sensitivity while giving your solution capital letter ≠ small letter
# If it is a string don't write quotes in the solution.**

# %%
df_even_even = df.iloc[0::2,0::2]

# %%
df_even_even = df_odd_even.reset_index(drop=True)

# %%
df_even_even.iloc[255,3]
# Out:
# 'Detached House'

# %% [markdown]
# **6- Determine the number of samples (rows) in the dataset that belong to the six most recent years, based on the provided data**

# %%
df['Year'].unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022])

# %%
df[df['Year'].isin([2017, 2018, 2019, 2020, 2021, 2022])].shape[0]
# Out:
# 4749

# %% [markdown]
# **7- Determine the number of samples (rows) in the dataset which has num_rooms = 3 and num_bathrooms = 3**

# %%
df[(df['num_rooms'] == 3)&(df['num_bathrooms'] == 3)].shape[0]
# Out:
# 2730

# %% [markdown]
# **8-Determine the number of samples (rows) in the dataset which has num_rooms = 3 or num_bathrooms = 3**

# %%
df[(df['num_rooms'] == 3)|(df['num_bathrooms'] == 3)].shape[0]
# Out:
# 8591

# %% [markdown]
# **9- In the Year 2022, how many houses (rows) located in the Greenwich Locality have exactly num_room == 3, and facing towards either the North or East?**

# %%
df[(df['Year']==2022)&(df['Locality']=='Greenwich')&(df['num_rooms']==3)&(df['Face'].isin(['North','East']))].shape[0]
# Out:
# 42

# %% [markdown]
# **10- Calculate the number of samples(rows) that correspond to the month of August across all the years.?**

# %%
def monthe(date):
  year,month,day = date.split('-')
  if month == '08':
    return True
  else:
    return False

df['Date'].apply(monthe).sum()
# Out:
# 1050

# %% [markdown]
# **11- According to the data which Locality have highest average Sale Price?**

# %%
df[['Locality','Sale Price']].groupby('Locality').mean().sort_values('Sale Price',ascending=False)
# Out:
#                  Sale Price
# Locality
# Greenwich      2.270224e+06
# Fairfield      7.277225e+05
# Stamford       6.305313e+05
# Norwalk        5.590959e+05
# West Hartford  3.385472e+05
# Bridgeport     1.740953e+05
# Waterbury      1.062152e+05
